# %%
pip install google-maps-reviews
# Out:
# ...
#
# ...

# %%
from google_maps_reviews import ReviewsClient

client = ReviewsClient(api_key='AIzaSyDbfTgR1s2l7BrDoe932RfXkKND7GnpCd0')

# %%
client

# %%
pip install googlemaps
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40750 sha256=ab0da25ee452805e82b0c03db4572ae773e4b9e76b2773a4102d6c7edd02d603
#   Stored in directory: c:\users\anag\appdata\local\pip\cache\wheels\f1\09\77\3cc2f5659cbc62341b30f806aca2b25e6a26c351daa5b1f49a
# Successfully built googlemaps
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import googlemaps
import pandas as pd

# Replace with your API key
api_key = "AIzaSyDbfTgR1s2l7BrDoe932RfXkKND7GnpCd0"

# Create Google Maps client object
client = googlemaps.Client(key=api_key)

# %%
# Define place name
place_name = "Memphis Seoul"

# Get place details
place_details = client.places(place_name)

# Extract place ID
place_id = place_details["results"][0]["place_id"]

# %%
place_details
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': '569 Lincoln Pl, Brooklyn, NY 11238, United States',
#    'geometry': {'location': {'lat': 40.6717258, 'lng': -73.9579098},
#     'viewport': {'northeast': {'lat': 40.67301497989272,
#       'lng': -73.95660887010727},
#      'southwest': {'lat': 40.67031532010728, 'lng': -73.95930852989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Memphis Seoul',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1154,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100347822687163365487">A Google User</a>'],
# ...

# %%
import googlemaps
import pandas as pd

# Replace with your API key
api_key = "AIzaSyDbfTgR1s2l7BrDoe932RfXkKND7GnpCd0"

# Create Google Maps client object
client = googlemaps.Client(key=api_key)

# List of target locations
locations = ['Cherry Hill', 'Marlton', 'Mount Laurel', 'Trenton', 'Voorhees',
       'Sewell', 'Moorestown', 'Medford', 'Haddonfield', 'Burlington',
       'Woodbury', 'Collingswood', 'Sicklerville', 'Pennsauken', 'Maple Shade',
       'Glassboro', 'Blackwood', 'Turnersville', 'Lambertville', 'Deptford',
       'Cinnaminson', 'Ewing', 'Bordentown', 'Mount Holly', 'Williamstown',
       'Camden', 'Delran', 'Clementon', 'Berlin', 'Swedesboro', 'West Berlin',
       'Audubon', 'Voorhees Township', 'Haddon Township', 'Mullica Hill',
       'Runnemede', 'Willingboro', 'Lumberton', 'Pitman', 'Hamilton',
       'Ewing Township', 'Haddon Heights', 'Bellmawr', 'Somerdale',
       'Hainesport', 'Lindenwold', 'Stratford', 'West Deptford',
       'Merchantville', 'Evesham Township', 'Oaklyn', 'Pennsville', 'Palmyra',
       'Westampton', 'Gloucester City', 'Deptford Township', 'Barrington',
       'Mantua', 'Pennsauken Township', 'Magnolia', 'Mt. Laurel', 'Columbus',
       'Westmont', 'Westville', 'Hamilton Township', 'Woodbury Heights',
       'Mount Ephraim', 'Brooklawn', 'Hammonton', 'Woodstown', 'Atco',
       'Southampton', 'Laurel Springs', 'Franklinville', 'Riverside',
       'Glendora', 'Maple Shade Township', 'Gloucester Township', 'Elmer',
       'Paulsboro', 'Clayton', 'Washington Township', 'Gibbsboro', 'Lawnside',
       'Pine Hill', 'Evesham', 'Penns Grove', 'Wenonah', 'Salem', 'Riverton',
       'Mt Laurel', 'Tabernacle', 'Pilesgrove', 'Beverly', 'Thorofare',
       'Malaga', 'Shamong', 'Gibbstown', 'Clarksboro', 'Carneys Point','Lawrenceville', 'Logan Township', 'Monroe Township',
       'Mount Laurel Township', 'Eastampton', 'Pennington',
       'Woolwich Township', 'Pemberton', 'Florence', 'Monroeville',
       'Burlington Township', 'Vincentown', 'Waterford Works',
       'Harrison Township', 'Mantua Township', 'Lawrence Township',
       'Titusville', 'Newfield', 'Pennsville Township', 'Winslow Township',
       'National Park', 'Medford Lakes', 'Roebling', 'Mansfield', 'Delanco',
       'Erial', 'West Trenton', 'Mt Holly', 'Berlin Township',
       'Florence Township', 'Mt Laurel Township', 'Mickleton',
       'Southampton Township', 'Chesilhurst', 'Mt. Ephraim', 'Pittsgrove',
       'Cedar Brook', 'Eastampton Township', 'Mt.Laurel', 'Franklin',
       'Hi-Nella', 'Chesterfield', 'Winslow', 'Willingboro Township',
       'Jobstown', 'Moorestown-Lenola', 'Oldmans Township', 'Mount Royal',
       'Mercerville', 'Haddon', 'Philadelphia', 'Upper Pittsgrove', 'Richwood',
       'Grenloch', 'Haddon Twp', 'Bridgeport', 'Oldmans', 'Lawrence',
       'Hopewell Township', 'Alloway', 'Folsom', 'South Harrison Township',
       'Fieldsboro', 'Cherry Hill Mall', 'Springfield', 'TRENTON',
       'Carneys Point', 'Rancocas', 'Bridgeton', 'Delran Twp', 'Monroe',
       'Woodbury Hts.', 'Evshm Twp', 'Cherry Hill,', 'North Maple Shade',
       'Stone Harbor', 'Pedricktown', 'Gloucester', 'Southampton ', 'MARLTON',
       'West Collingswood Heights', 'DELRAN', 'Washington', 'Glendale',
       'Delran Township', 'Blackwood ', 'Hatboro', 'Hi Nella', 'Ewing Twp',
       'Berlin Boro', 'W. Berlin', 'Westhampton', 'South Burlington',
       'Hurffville', 'Haddon township', 'South Cherry Hill', 'Vineland',
       'Had Twp', 'Deptford Twp','Tren', 'Mt Laurel Twp, NJ', 'Pennsaulen', 'Bordentown Township',
       'Cedarbrook', 'West Deptford Townsh', 'Pine HIll', 'Woolwich Twp',
       'Almonesson', 'Hadden', 'Audubon ', 'W Cherry Hill', 'New Jersey',
       'Westampton Township', 'Pittsgrove Township', 'Flanders',
       'South Cinnaminson', 'West Mount Holly', 'Hilltop', 'Elk Township',
       'Woolwich Twp.', 'sewell', 'Swedesboro ', 'Mt Ephraim', 'Hamiltion',
       'pennsauken', 'Freehold', 'Mt. Holly', 'Quinton', 'maple shade nj',
       'Washington Twp', 'West  Deptford', 'Cherry Hil', 'North Marlton',
       'Echelon', 'Crosswicks', 'Westmont - Haddon Towsship']

# Desired number of restaurants per location (adjust as needed)
restaurants_per_location = 100

# Initialize empty list for storing restaurant data
restaurant_data = []

# Loop through each location
for location in locations:
    # Perform multiple API calls to retrieve data in chunks
    for offset in range(0, restaurants_per_location // 20, 20):
        # Build search query
        query = f"restaurants near {location}"

        # Get place details for the current chunk
        place_details = client.places(query=query, radius=5000, page_token=None)

        # Extract relevant data from each result
        for result in place_details["results"]:
            restaurant_data.append({
                "name": result["name"],
                "address": result["formatted_address"],
                "rating": result["rating"],
                "location": location,
                "latitude": result["geometry"]["location"]["lat"],
                "longitude": result["geometry"]["location"]["lng"],
                "total_ratings": result["user_ratings_total"]
            })

        # Check if API calls reached daily limit
        if place_details["status"] == "OVER_QUERY_LIMIT":
            print("Warning: Daily API limit reached. Stop processing.")
            break

# Convert list of dictionaries to pandas DataFrame
df_restaurants = pd.DataFrame(restaurant_data)

# Export data to CSV file
df_restaurants.to_csv("nj_restaurants_data.csv", index=False)

print("Restaurant data collected and saved to restaurants_data.csv")
# Out:
# Restaurant data collected and saved to restaurants_data.csv

# %%
df_restaurants
# Out:
#                                              name  \
# 0                                     TGI Fridays
# 1                          Applebee's Grill + Bar
# 2                                    Silver Diner
# 3                                      Kaminski's
# 4     The Farm and Fisherman Tavern - Cherry Hill
# ...                                           ...
# 4449                                 Nick & Joe's
# 4450                                  Asian Yummy
# 4451                         Brewers Towne Tavern
# 4452                                 Dar's Steaks
# 4453                               Domino's Pizza
#
#                                                 address  rating  \
# 0      2125 NJ-38, Cherry Hill, NJ 08002, United States     3.5
# 1     108 Haddonfield Rd, Cherry Hill, NJ 08002, Uni...     4.0
# 2      2131 NJ-38, Cherry Hill, NJ 08002, United States     4.3
# 3     1424 Brace Rd, Cherry Hill, NJ 08034, United S...     4.3
# ...

# %%
df_restaurants['location'][0:50]
# Out:
# 0      Cherry Hill
# 1      Cherry Hill
# 2      Cherry Hill
# 3      Cherry Hill
# 4      Cherry Hill
# 5      Cherry Hill
# 6      Cherry Hill
# 7      Cherry Hill
# 8      Cherry Hill
# 9      Cherry Hill
# 10     Cherry Hill
# 11     Cherry Hill
# 12     Cherry Hill
# 13     Cherry Hill
# 14     Cherry Hill
# 15     Cherry Hill
# 16     Cherry Hill
# 17     Cherry Hill
# 18     Cherry Hill
# 19     Cherry Hill
# 20         Marlton
# 21         Marlton
# 22         Marlton
# 23         Marlton
# 24         Marlton
# 25         Marlton
# 26         Marlton
# 27         Marlton
# 28         Marlton
# 29         Marlton
# 30         Marlton
# 31         Marlton
# 32         Marlton
# 33         Marlton
# 34         Marlton
# 35         Marlton
# 36         Marlton
# 37         Marlton
# 38         Marlton
# 39         Marlton
# 40    Mount Laurel
# 41    Mount Laurel
# 42    Mount Laurel
# 43    Mount Laurel
# 44    Mount Laurel
# 45    Mount Laurel
# 46    Mount Laurel
# ...

# %% [markdown]
# Remember Carney's Point and Deptford Twp’
